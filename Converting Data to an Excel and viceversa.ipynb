# %% [markdown]
# ## Converting Data to an Excel and viceversa
# When we asked the students for their names and personal data, an excel file similar to the one you can find under the name `Data.xlsx` was generated by the form application. There, the organizers made the form such that the name and the surnames of the students appeared under the same field. However, when we needed to register you in the *moodle*, we needed to upload an excel (or even a `.csv` separating the fields by commas would be enough), with the fields **username**, **name**, **surnames**, **email**, where the username for a person called `Alberto Einstein Melero`, should be `alber.einstein` (note the lower-case!).
#
# Of course for a list of almost 50 students, we would not do this by hand, you should not either! Do it!
#
# Given the excel `Data.xlsx`, where data is as:
#
#     "Nombre y Apellidos"           "correo"                   "Eres de la SCN2?"
#     ------------------------------------------------------------------------------------
#     Alberto Einstein Melero     realtividad@gmail.com               Sí!
#             ...                         ...                         ...
#
# Create a new excel called `NormalizedData.xlsx`, where data is as:
#
#         "username"         "name"       "surnames"              "email"
#     ------------------------------------------------------------------------------------
#     alberto.einstein       Alberto      Einstein Melero       realtividad@gmail.com
#             ...              ...             ...                      ...

# %%
import pandas as pd

# %% [markdown]
# Convert Excel to a dictionary:

# %%
mydict = pd.read_excel("Data.xlsx").to_dict(orient='list')

# %%
print(mydict)
# Out:
# {'Nombres y Apellidos': ['Aramethion Aldalome Feanor', 'Celebornar Wandlimb', 'Elenweyr Dunedain Calenardhon', 'Finwethen Elendil', 'Galadrieth Orodreth Dunedain', 'Ilmarinor Undomiel Haldadrim', 'Kaelthasir Mithrandir Elessar', 'Lathalasien Ulmo Eldamar', 'Melianiel Ardalome Zirakzigil', 'Nimrodelia Luthien Luthien', 'Orlandothen Dunedain Elessar', 'Qwenaelar Ulmo Anarion', 'Rivendalian Radagast Mithrandir', 'Sylviathen Glorfindel Isilme', 'Taurionas Sauron Xenithar', 'Ulmarenthor Eldamar Calenardhon', 'Vardaeris Valinor Mithrandir', 'Wintersonas Calenardhon Eldamar', 'Xanthienor Thangorodrim Elessar', 'Yavannethel Haldadrim Mithrandir', 'Zephyrusil Wandlimb Feanor', 'Aerithien Noldor', 'Belthienor Noldor Beleriand', 'Caelthoris Silmarien Mithrandir', 'Dunthoras Valinor Luthien', 'Eoltharen Eluchil Sindar', 'Faelivion Sauron Dunedain', 'Gaelindor Beleriand Ulmo', 'Helithelas Sauron Silmarien', 'Isilthor Isilme', 'Jarnethon Xenithar Imladris', 'Kanithoril Luthien Anarion', 'Lindarieth Feanor Ulmo', 'Maelithel Eldamar Thangorodrim', 'Naelindon Elendil Dunedain', 'Olorinor Imladris', 'Pelenweth Echoriath Glorfindel', 'Quenithel Anarion Valinor', 'Rianthorin Thangorodrim Sauron', 'Saeliviel Anarion Ulmo', 'Thranduilin Beleriand Aranwe', 'Undomielor Undomiel Xenithar', 'Vanyarinor Radagast Undomiel', 'Wilwarinor Beleriand', 'Xalanthir Zirakzigil Elessar', 'Yavaniel Silmarien Ardalome', 'Ziraelas Zirakzigil Isilme'], 'Correo': ['aramethion877@teldrassil.net', 'celebornar890@silvanasonguard.com', 'elenweyr503@queldore.net', 'finwethen732@darnassus.net', 'galadrieth55@arvendel.com', 'ilmarinor484@arvendel.com', 'kaelthasir189@sindorei.com', 'lathalasien523@anaralah.net', 'melianiel395@silvanasonguard.com', 'nimrodelia242@sindorei.com', 'orlandothen416@darnassus.net', 'qwenaelar602@queldore.net', 'rivendalian314@arvendel.com', 'sylviathen139@anaralah.net', 'taurionas147@lunarglade.net', 'ulmarenthor526@arvendel.com', 'vardaeris750@arvendel.com', 'wintersonas404@teldrassil.net', 'xanthienor100@arvendel.com', 'yavannethel349@queldore.net', 'zephyrusil791@ilithyra.com', 'aerithien186@anaralah.net', 'belthienor136@ilithyra.com', 'caelthoris271@queldore.net', 'dunthoras369@queldore.net', 'eoltharen821@ilithyra.com', 'faelivion607@arvendel.com', 'gaelindor601@altorrel.com', 'helithelas12@queldore.net', 'isilthor948@lunarglade.net', 'jarnethon852@silvanasonguard.com', 'kanithoril400@anaralah.net', 'lindarieth607@arvendel.com', 'maelithel889@arvendel.com', 'naelindon475@darnassus.net', 'olorinor486@anaralah.net', 'pelenweth659@silvanasonguard.com', 'quenithel648@ilithyra.com', 'rianthorin73@arvendel.com', 'saeliviel760@queldore.net', 'thranduilin337@teldrassil.net', 'undomielor140@queldore.net', 'vanyarinor498@darnassus.net', 'wilwarinor267@arvendel.com', 'xalanthir978@altorrel.com', 'yavaniel425@arvendel.com', 'ziraelas942@arvendel.com'], 'Eres de la SCN2?': ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes']}

# %% [markdown]
# Create a new dictionary with username (name.surname), name, surname and email:

# %%
new_dict = {
    'username': [],
    'name': [],
    'surnames': [],
    'email': []
}

for name, email in zip(mydict['Nombres y Apellidos'], mydict['Correo']):
    # Name and Surname
    split_name = name.split(' ')
    first_name = split_name[0]
    last_name = split_name[-1]
    last_name2 = split_name[-2] if len(split_name) > 2 else ''
    
    # Crete username
    username = '{}.{}'.format(first_name.lower(), last_name.lower())
    
    # Add values to the new dictionary
    new_dict['username'].append(username)
    new_dict['name'].append(first_name)
    new_dict['surnames'].append(last_name + ' ' + last_name2)
    new_dict['email'].append(email)

print(new_dict)
# Out:
# {'username': ['aramethion.feanor', 'celebornar.wandlimb', 'elenweyr.calenardhon', 'finwethen.elendil', 'galadrieth.dunedain', 'ilmarinor.haldadrim', 'kaelthasir.elessar', 'lathalasien.eldamar', 'melianiel.zirakzigil', 'nimrodelia.luthien', 'orlandothen.elessar', 'qwenaelar.anarion', 'rivendalian.mithrandir', 'sylviathen.isilme', 'taurionas.xenithar', 'ulmarenthor.calenardhon', 'vardaeris.mithrandir', 'wintersonas.eldamar', 'xanthienor.elessar', 'yavannethel.mithrandir', 'zephyrusil.feanor', 'aerithien.noldor', 'belthienor.beleriand', 'caelthoris.mithrandir', 'dunthoras.luthien', 'eoltharen.sindar', 'faelivion.dunedain', 'gaelindor.ulmo', 'helithelas.silmarien', 'isilthor.isilme', 'jarnethon.imladris', 'kanithoril.anarion', 'lindarieth.ulmo', 'maelithel.thangorodrim', 'naelindon.dunedain', 'olorinor.imladris', 'pelenweth.glorfindel', 'quenithel.valinor', 'rianthorin.sauron', 'saeliviel.ulmo', 'thranduilin.aranwe', 'undomielor.xenithar', 'vanyarinor.undomiel', 'wilwarinor.beleriand', 'xalanthir.elessar', 'yavaniel.ardalome', 'ziraelas.isilme'], 'name': ['Aramethion', 'Celebornar', 'Elenweyr', 'Finwethen', 'Galadrieth', 'Ilmarinor', 'Kaelthasir', 'Lathalasien', 'Melianiel', 'Nimrodelia', 'Orlandothen', 'Qwenaelar', 'Rivendalian', 'Sylviathen', 'Taurionas', 'Ulmarenthor', 'Vardaeris', 'Wintersonas', 'Xanthienor', 'Yavannethel', 'Zephyrusil', 'Aerithien', 'Belthienor', 'Caelthoris', 'Dunthoras', 'Eoltharen', 'Faelivion', 'Gaelindor', 'Helithelas', 'Isilthor', 'Jarnethon', 'Kanithoril', 'Lindarieth', 'Maelithel', 'Naelindon', 'Olorinor', 'Pelenweth', 'Quenithel', 'Rianthorin', 'Saeliviel', 'Thranduilin', 'Undomielor', 'Vanyarinor', 'Wilwarinor', 'Xalanthir', 'Yavaniel', 'Ziraelas'], 'surnames': ['Feanor Aldalome', 'Wandlimb ', 'Calenardhon Dunedain', 'Elendil ', 'Dunedain Orodreth', 'Haldadrim Undomiel', 'Elessar Mithrandir', 'Eldamar Ulmo', 'Zirakzigil Ardalome', 'Luthien Luthien', 'Elessar Dunedain', 'Anarion Ulmo', 'Mithrandir Radagast', 'Isilme Glorfindel', 'Xenithar Sauron', 'Calenardhon Eldamar', 'Mithrandir Valinor', 'Eldamar Calenardhon', 'Elessar Thangorodrim', 'Mithrandir Haldadrim', 'Feanor Wandlimb', 'Noldor ', 'Beleriand Noldor', 'Mithrandir Silmarien', 'Luthien Valinor', 'Sindar Eluchil', 'Dunedain Sauron', 'Ulmo Beleriand', 'Silmarien Sauron', 'Isilme ', 'Imladris Xenithar', 'Anarion Luthien', 'Ulmo Feanor', 'Thangorodrim Eldamar', 'Dunedain Elendil', 'Imladris ', 'Glorfindel Echoriath', 'Valinor Anarion', 'Sauron Thangorodrim', 'Ulmo Anarion', 'Aranwe Beleriand', 'Xenithar Undomiel', 'Undomiel Radagast', 'Beleriand ', 'Elessar Zirakzigil', 'Ardalome Silmarien', 'Isilme Zirakzigil'], 'email': ['aramethion877@teldrassil.net', 'celebornar890@silvanasonguard.com', 'elenweyr503@queldore.net', 'finwethen732@darnassus.net', 'galadrieth55@arvendel.com', 'ilmarinor484@arvendel.com', 'kaelthasir189@sindorei.com', 'lathalasien523@anaralah.net', 'melianiel395@silvanasonguard.com', 'nimrodelia242@sindorei.com', 'orlandothen416@darnassus.net', 'qwenaelar602@queldore.net', 'rivendalian314@arvendel.com', 'sylviathen139@anaralah.net', 'taurionas147@lunarglade.net', 'ulmarenthor526@arvendel.com', 'vardaeris750@arvendel.com', 'wintersonas404@teldrassil.net', 'xanthienor100@arvendel.com', 'yavannethel349@queldore.net', 'zephyrusil791@ilithyra.com', 'aerithien186@anaralah.net', 'belthienor136@ilithyra.com', 'caelthoris271@queldore.net', 'dunthoras369@queldore.net', 'eoltharen821@ilithyra.com', 'faelivion607@arvendel.com', 'gaelindor601@altorrel.com', 'helithelas12@queldore.net', 'isilthor948@lunarglade.net', 'jarnethon852@silvanasonguard.com', 'kanithoril400@anaralah.net', 'lindarieth607@arvendel.com', 'maelithel889@arvendel.com', 'naelindon475@darnassus.net', 'olorinor486@anaralah.net', 'pelenweth659@silvanasonguard.com', 'quenithel648@ilithyra.com', 'rianthorin73@arvendel.com', 'saeliviel760@queldore.net', 'thranduilin337@teldrassil.net', 'undomielor140@queldore.net', 'vanyarinor498@darnassus.net', 'wilwarinor267@arvendel.com', 'xalant ...

# %% [markdown]
# Convert dictonary to a new Excel:

# %%
pd.DataFrame( data = new_dict ).to_excel("NormalizedData.xlsx", index=False)
